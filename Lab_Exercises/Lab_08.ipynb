# %% [markdown]
# # LAB Sheet-08: Decision Tree for Classification
#
# ### Submitted by: Vatsalya Gupta, SC19B098, B.Tech. ECE VII Semester

# %% [markdown]
# ## 1. Training a Decision Tree
# We'll use the pre-loaded [Iris](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html) data set and build a [Decision Tree Classifier](https://scikit-learn.org/stable/modules/tree.html).
#
# Start by loading the dataset and building a decision tree classifier.
#
# (hint: Use $\texttt{DecisionTreeClassifier}$ model from $\texttt{sklearn.tree}$)

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
iris = load_iris()
X = iris.data
y = iris.target
features = iris.feature_names

# %% [markdown]
# 1. Read details about the Iris data set [here](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html) and [here](https://en.wikipedia.org/wiki/Iris_flower_data_set). What features are in the data set? What is the target (y) variable and what possible values does it take on?
# 2. Which features are we keeping for our training set (X)? How would you change the code to choose different features? When you finish this tutorial, come back and modify this code to see how it influeces the results.
# 3. Read an [explanation of Decision Trees](https://scikit-learn.org/stable/modules/tree.html) and then look at the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) for the function to see what parameters exist.
# 4. What version of decision trees is implemented by scikit-learn? How does it relate to those discussed in class?
# 5. Note that information gain is not the default selection criteria. How do we change that (experiment with this later). How does the default compare to information gain? Here is a [post](http://haohanw.blogspot.com/2014/08/ml-decision-tree-rule-selection.html) with some useful information.
# 5. $\texttt{max_depth}$ is set to 2. How does this related to our discussion about stopping criteria and overfitting? How do we prevent the use of $\texttt{max_depth}$. Can you find other parameters to prevent overfitting? Again, I recommend coming back to this later and playing around with different options in the code.

# %% [markdown]
# Fit the built model to the data.

# %%
clf = DecisionTreeClassifier(max_depth = 2)
clf = clf.fit(X, y)

# %% [markdown]
# ## 2. Visualize the Tree
# Now, visualize your tree.
#
# (hint: Use $\texttt{tree.plot_tree}$ from $\texttt{sklearn}$ to do so.)

# %%
visualize_tree = plot_tree(decision_tree = clf, feature_names = features, filled = True)

# %% [markdown]
# ## 3. Predicting classes and class probabilities

# %% [markdown]
# Now predict the class probabilities and show the predicted class for a test example having the following attributes.
# sepal length = 5, sepal width = 1.5, petal length = 4, petal width = 2.

# %%
X_test = [[5, 1.5, 4, 2]]
clf.predict_proba(X_test)
# Out:
# array([[0.        , 0.02173913, 0.97826087]])

# %%
clf.predict(X_test, check_input=True)
# Out:
# array([2])
